# %%
#bai1
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('https://raw.githubusercontent.com/ltdaovn/dataset/master/gym_height.csv', index_col=0)
df.head()
df.hist(column='height', grid=False)
df.hist(column='height', grid=False, bins=20)

df.hist(column='height', by='sex', grid=False, figsize = (14,7))
# Out:
# array([<Axes: title={'center': 'f'}>, <Axes: title={'center': 'm'}>],
#       dtype=object)

# %%
#bai2
import seaborn as sns

tips = sns.load_dataset('tips')
tips.head()

sns.boxplot(y=tips["total_bill"])

sns.boxplot(x="day", y="total_bill", data=tips)

sns.boxplot(x="day", y="total_bill", hue="smoker", data=tips, palette="Set3")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#bai3
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("https://raw.githubusercontent.com/ltdaovn/dataset/master/turtle.csv", delimiter='\t')
df.head()
#df.describe()

df.plot.scatter(x = 'width', y = 'height')

x = df.width
y = df.height
plt.scatter(x,y)

df.corr()

plt.figure(figsize=(6, 5))

#sns.heatmap(df.corr(), annot=True)
sns.heatmap(df.corr())
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: >

# %%
#bai4
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns 
from matplotlib.lines import Line2D 

df = sns.load_dataset('diamonds')

sns.lmplot(x='carat', y='price', data=df, hue='color', fit_reg=False)

# %%
#bai5
import seaborn
  
tip = seaborn.load_dataset('tips')
  
seaborn.lmplot(x="total_bill",
               y="size",
               hue="sex",
               data=tip)

# %%
#bai6a
import seaborn as sns
import pandas as pd

ob = pd.read_csv('https://raw.githubusercontent.com/ltdaovn/dataset/master/obesity.csv')
ob.head()

sns.boxplot(x="gender", y="pcfat", data=ob)
# Out:
# <Axes: xlabel='gender', ylabel='pcfat'>

# %%
#bai6b
import seaborn as sns
import pandas as pd

ob = pd.read_csv('https://raw.githubusercontent.com/ltdaovn/dataset/master/obesity.csv')
ob.head()

sns.boxplot(x="age", y="pcfat", hue="gender", data=ob)
# Out:
# <Axes: xlabel='age', ylabel='pcfat'>

# %%
#bai6c
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('https://raw.githubusercontent.com/ltdaovn/dataset/master/obesity.csv')
df.head()
sns.histplot(hue="gender", y="pcfat", common_norm=False, data=df)
# Out:
# <Axes: xlabel='Count', ylabel='pcfat'>

# %%
#bai6d
import seaborn as sns
import pandas as pd

ob = pd.read_csv('https://raw.githubusercontent.com/ltdaovn/dataset/master/obesity.csv')
ob.head()

sns.histplot(x="age", y="wbbmd", hue="gender", data=ob)
# Out:
# <Axes: xlabel='age', ylabel='wbbmd'>

# %%
#bai6e
import seaborn as sns
import pandas as pd

ob = pd.read_csv('https://raw.githubusercontent.com/ltdaovn/dataset/master/obesity.csv')
ob.head()

sns.histplot(x="bmi", y="pcfat", hue="gender", data=ob)
# Out:
# <Axes: xlabel='bmi', ylabel='pcfat'>
